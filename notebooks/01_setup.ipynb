# %% [markdown]
# # Aegis Project Setup
#
# This notebook sets up the environment and verifies that all dependencies and data files are in place.
#
# ## Overview
# 1. Install required packages
# 2. Verify Python environment
# 3. Create project directories
# 4. Check for dataset files

# %%
# Install all required packages (uncomment if running for first time)
# %pip install -r ../requirements.txt

# Or install individual packages:
# %pip install torch torch-geometric numpy pandas scikit-learn matplotlib seaborn networkx tqdm
# Out:
# Requirement already satisfied: torch in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (2.9.1)
# Requirement already satisfied: torch-geometric in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (2.7.0)
# Requirement already satisfied: numpy in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (2.4.0)
# Requirement already satisfied: pandas in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: networkx in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (3.6.1)
# Requirement already satisfied: tqdm in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (4.67.1)
# Requirement already satisfied: filelock in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: aiohttp in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch-geometric) (3.13.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch-geometric) (7.2.1)
# Requirement already satisfied: pyparsing in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch-geometric) (3.3.1)
# Requirement already satisfied: requests in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch-geometric) (2.32.5)
# Requirement already satisfied: xxhash in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: colorama in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from aiohttp->torch-geometric) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->torch-geometric) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from requests->torch-geometric) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from requests->torch-geometric) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tusha\documents\ut_dallas\acm_sp26\kryptos---quantum-blockchain-fraud-detection\venv\lib\site-packages (from requests->torch-geometric) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Install Dependencies
#
# Install all required Python packages. This may take a few minutes on first run.

# %%
import sys
import os
import torch
from pathlib import Path

print(f"Python: {sys.version}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# Python: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# PyTorch: 2.9.1+cpu
# CUDA available: False

# %% [markdown]
# ## 2. Verify Environment
#
# Check Python version, PyTorch installation, and CUDA availability.

# %%
# Define required directories
dirs = ['data', 'artifacts', 'figures', 'src']

# Create each directory if it doesn't exist
for d in dirs:
    Path(d).mkdir(parents=True, exist_ok=True)
    print(f"✓ Created/verified: {d}")

# Create src package
Path('src/__init__.py').touch()
print(f"✓ Initialized src package")
# Out:
# ✓ Created/verified: data
# ✓ Created/verified: artifacts
# ✓ Created/verified: figures
# ✓ Created/verified: src
# ✓ Initialized src package

# %% [markdown]
# ## 3. Create Project Directories
#
# Create the required directory structure for data, artifacts, figures, and source code.

# %%
# List of required dataset files
required_files = [
    'data/txs_features.csv',
    'data/txs_edgelist.csv',
    'data/txs_classes.csv'
]

# Check each file
print("Dataset files status:")
all_present = True
for file_path in required_files:
    exists = os.path.exists(file_path)
    status = "✓" if exists else "✗"
    print(f"  {status} {file_path}")
    if not exists:
        all_present = False

# Summary
print()
if all_present:
    print("✅ All dataset files found! Ready to proceed.")
else:
    print("⚠️  Some dataset files are missing. Please add them to the data/ directory.")
# Out:
# Dataset files status:
#   ✗ data/txs_features.csv
#   ✗ data/txs_edgelist.csv
#   ✗ data/txs_classes.csv
#
# ⚠️  Some dataset files are missing. Please add them to the data/ directory.

# %% [markdown]
# ---
#
# ## ✅ Setup Complete!
#
# If all checks passed, proceed to **02_data_graph.ipynb** to load and build the transaction graph.

# %% [markdown]
# ## 4. Verify Dataset Files
#
# Check that all required dataset files are present in the `data/` directory.
#
# **Required files:**
# - `txs_features.csv` - Transaction node features
# - `txs_edgelist.csv` - Transaction graph edges
# - `txs_classes.csv` - Transaction labels (1=illicit, 2=licit, 3=unknown)
